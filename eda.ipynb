# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet("steam_top_300_with_youtube.parquet")

# %%
df.head()
# Out:
#    appid                            name  release_date  \
# 0    100  Counter-Strike: Condition Zero   Mar 1, 2004
# 1    130           Half-Life: Blue Shift   1 Jun, 2001
# 2    150             Counter-Strike Beta
# 3    620                        Portal 2  18 Apr, 2011
# 4    630                     Alien Swarm  Jul 19, 2010
#
#                    genres          developers publishers     price  \
# 0                [Action]             [Valve]    [Valve]     $9.99
# 1                [Action]  [Gearbox Software]    [Valve]     ₹ 250
# 2                [Action]                  []         []      None
# 3     [Action, Adventure]             [Valve]    [Valve]  ₩ 11,000
# 4  [Action, Free To Play]             [Valve]    [Valve]      None
#
#    metacritic_score  video_count  total_views
# 0              65.0            5     51092231
# 1              71.0            5     12370177
# 2               NaN            5     47480546
# 3              95.0            5    152230849
# ...

# %%
print(df['name'])
# Out:
# 0                         Counter-Strike: Condition Zero
# 1                                  Half-Life: Blue Shift
# 2                                    Counter-Strike Beta
# 3                                               Portal 2
# 4                                            Alien Swarm
#                              ...
# 295    Napoleon: Total War - Heroes of the Napoleonic...
# 296         Napoleon: Total War™ - Coalition Battle Pack
# 297       Napoleon: Total War™ - The Peninsular Campaign
# 298                        Sonic & SEGA All-Stars Racing
# 299                             Aliens vs. Predator Demo
# Name: name, Length: 300, dtype: object

# %%
len(df)
# Out:
# 50
